# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MauricioRR-Tec/Machine-Learning/blob/master/Notebooks/Module_2/SML_Examples.ipynb)

# %% [markdown]
# # Examples of Classification

# %%
# import the necessary packages
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.datasets import load_iris
import argparse

## construct the argument parser and parse the arguments
#ap = argparse.ArgumentParser()
#ap.add_argument("-m", "--model", type=str, default="knn",
#	help="type of python machine learning model to use")
#args = vars(ap.parse_args())

# define the dictionary of models our script can use, where the key
# to the dictionary is the name of the model (supplied via command
# line argument) and the value is the model itself
models = {
	"knn": KNeighborsClassifier(n_neighbors=1),
	"naive_bayes": GaussianNB(),
	"logit": LogisticRegression(solver="lbfgs", multi_class="auto"),
	"svm": SVC(kernel="rbf", gamma="auto"),
	"decision_tree": DecisionTreeClassifier(),
	"random_forest": RandomForestClassifier(n_estimators=100),
	"mlp": MLPClassifier()
}

# load the Iris dataset and perform a training and testing split,
# using 75% of the data for training and 25% for evaluation
print("[INFO] loading data...")
dataset = load_iris()
(trainX, testX, trainY, testY) = train_test_split(dataset.data, dataset.target, random_state=3, test_size=0.25)

# train the model
print("[INFO] using '{}' model".format("knn"))
model = models["knn"]
model.fit(trainX, trainY)

# make predictions on our data and show a classification report
print("[INFO] evaluating...")
predictions = model.predict(testX)
print(classification_report(testY, predictions, target_names=dataset.target_names))
# Out:
# [INFO] loading data...
# [INFO] using 'knn' model
# [INFO] evaluating...
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       0.92      0.92      0.92        12
#    virginica       0.91      0.91      0.91        11
#
#     accuracy                           0.95        38
#    macro avg       0.94      0.94      0.94        38
# weighted avg       0.95      0.95      0.95        38

# %% [markdown]
# # "Basic" NN

# %%
from keras.models import Sequential
from keras.layers.core import Dense
from keras.optimizers import SGD
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.datasets import load_iris

# %%
# load the Iris dataset and perform a training and testing split,
# using 75% of the data for training and 25% for evaluation
print("[INFO] loading data...")
dataset = load_iris()
(trainX, testX, trainY, testY) = train_test_split(dataset.data, dataset.target, test_size=0.25)
# Out:
# [INFO] loading data...

# %%
# encode the labels as 1-hot vectors
lb = LabelBinarizer()
trainY = lb.fit_transform(trainY)
testY = lb.transform(testY)

# %%
# define the 4-3-3-3 architecture using Keras
model = Sequential()
model.add(Dense(3, input_shape=(4,), activation="sigmoid"))
model.add(Dense(3, activation="sigmoid"))
model.add(Dense(3, activation="softmax"))

# %%
# train the model using SGD
print("[INFO] training network...")
opt = SGD(lr=0.1, momentum=0.9, decay=0.1 / 250)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
H = model.fit(trainX, trainY, validation_data=(testX, testY), epochs=250, batch_size=16)
# Out:
# [INFO] training network...
# Epoch 1/250
# 7/7 [==============================] - 0s 21ms/step - loss: 1.1606 - accuracy: 0.2679 - val_loss: 1.1169 - val_accuracy: 0.0000e+00
# Epoch 2/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1053 - accuracy: 0.2946 - val_loss: 1.1336 - val_accuracy: 0.2895
# Epoch 3/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1091 - accuracy: 0.3482 - val_loss: 1.1078 - val_accuracy: 0.2895
# Epoch 4/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1188 - accuracy: 0.2500 - val_loss: 1.0947 - val_accuracy: 0.3947
# Epoch 5/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1138 - accuracy: 0.2946 - val_loss: 1.1238 - val_accuracy: 0.3158
# Epoch 6/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1056 - accuracy: 0.3661 - val_loss: 1.1220 - val_accuracy: 0.2895
# Epoch 7/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1019 - accuracy: 0.3482 - val_loss: 1.1020 - val_accuracy: 0.2895
# Epoch 8/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1113 - accuracy: 0.2679 - val_loss: 1.0962 - val_accuracy: 0.3158
# Epoch 9/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1283 - accuracy: 0.3393 - val_loss: 1.1148 - val_accuracy: 0.3158
# Epoch 10/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1094 - accuracy: 0.3125 - val_loss: 1.1286 - val_accuracy: 0.2895
# Epoch 11/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1146 - accuracy: 0.3482 - val_loss: 1.1072 - val_accuracy: 0.2895
# Epoch 12/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0990 - accuracy: 0.3661 - val_loss: 1.1101 - val_accuracy: 0.3158
# Epoch 13/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1046 - accuracy: 0.3393 - val_loss: 1.1057 - val_accuracy: 0.3158
# Epoch 14/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1013 - accuracy: 0.3304 - val_loss: 1.1086 - val_accuracy: 0.2895
# Epoch 15/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1023 - accuracy: 0.3482 - val_loss: 1.1026 - val_accuracy: 0.2895
# Epoch 16/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1089 - accuracy: 0.3482 - val_loss: 1.1146 - val_accuracy: 0.2895
# Epoch 17/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0990 - accuracy: 0.3482 - val_loss: 1.1047 - val_accuracy: 0.3158
# Epoch 18/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1159 - accuracy: 0.3393 - val_loss: 1.1073 - val_accuracy: 0.3158
# Epoch 19/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1064 - accuracy: 0.3125 - val_loss: 1.1124 - val_accuracy: 0.2895
# Epoch 20/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1031 - accuracy: 0.3482 - val_loss: 1.1053 - val_accuracy: 0.2895
# Epoch 21/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1013 - accuracy: 0.3482 - val_loss: 1.0999 - val_accuracy: 0.2895
# Epoch 22/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1064 - accuracy: 0.2679 - val_loss: 1.1150 - val_accuracy: 0.2895
# Epoch 23/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1037 - accuracy: 0.2768 - val_loss: 1.0986 - val_accuracy: 0.3158
# Epoch 24/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1012 - accuracy: 0.2679 - val_loss: 1.1068 - val_accuracy: 0.2895
# Epoch 25/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1059 - accuracy: 0.2321 - val_loss: 1.1045 - val_accuracy: 0.2895
# Epoch 26/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1029 - accuracy: 0.3482 - val_loss: 1.1138 - val_accuracy: 0.2895
# Epoch 27/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1003 - accuracy: 0.3482 - val_loss: 1.1085 - val_accuracy: 0.3158
# Epoch 28/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1099 - accuracy: 0.3393 - val_loss: 1.1260 - val_accuracy: 0.3158
# Epoch 29/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1042 - accuracy: 0.3393 - val_loss: 1.0981 - val_accuracy: 0.3158
# Epoch 30/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1006 - accuracy: 0.3036 - val_loss: 1.1015 - val_accuracy: 0.2895
# Epoch 31/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0995 - accuracy: 0.3482 - val_loss: 1.1081 - val_accuracy: 0.2895
# Epoch 32/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1045 - accuracy: 0.3482 - val_loss: 1.1183 - val_accuracy: 0.2895
# Epoch 33/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1078 - accuracy: 0.3393 - val_loss: 1.1087 - val_accuracy: 0.3158
# Epoch 34/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1030 - accuracy: 0.3125 - val_loss: 1.1082 - val_accuracy: 0.2895
# Epoch 35/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1053 - accuracy: 0.3393 - val_loss: 1.1000 - val_accuracy: 0.3158
# Epoch 36/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0998 - accuracy: 0.3393 - val_loss: 1.1056 - val_accuracy: 0.3158
# Epoch 37/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1024 - accuracy: 0.3482 - val_loss: 1.1207 - val_accuracy: 0.2895
# Epoch 38/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1014 - accuracy: 0.3482 - val_loss: 1.1042 - val_accuracy: 0.3158
# Epoch 39/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1057 - accuracy: 0.2679 - val_loss: 1.0959 - val_accuracy: 0.3947
# Epoch 40/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0990 - accuracy: 0.3393 - val_loss: 1.1085 - val_accuracy: 0.3158
# Epoch 41/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1074 - accuracy: 0.3393 - val_loss: 1.1227 - val_accuracy: 0.3158
# Epoch 42/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1051 - accuracy: 0.3304 - val_loss: 1.1023 - val_accuracy: 0.2895
# Epoch 43/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1062 - accuracy: 0.3482 - val_loss: 1.1191 - val_accuracy: 0.2895
# Epoch 44/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1042 - accuracy: 0.3482 - val_loss: 1.1056 - val_accuracy: 0.2895
# Epoch 45/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1064 - accuracy: 0.2321 - val_loss: 1.0983 - val_accuracy: 0.3158
# Epoch 46/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1032 - accuracy: 0.3393 - val_loss: 1.1017 - val_accuracy: 0.3158
# Epoch 47/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0996 - accuracy: 0.3393 - val_loss: 1.1117 - val_accuracy: 0.2895
# Epoch 48/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1045 - accuracy: 0.3482 - val_loss: 1.1091 - val_accuracy: 0.2895
# Epoch 49/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1001 - accuracy: 0.3482 - val_loss: 1.1148 - val_accuracy: 0.2895
# Epoch 50/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1032 - accuracy: 0.3482 - val_loss: 1.1124 - val_accuracy: 0.2895
# Epoch 51/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1032 - accuracy: 0.3482 - val_loss: 1.1018 - val_accuracy: 0.2895
# Epoch 52/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1064 - accuracy: 0.3482 - val_loss: 1.1113 - val_accuracy: 0.3158
# Epoch 53/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1022 - accuracy: 0.3393 - val_loss: 1.1013 - val_accuracy: 0.3158
# Epoch 54/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1064 - accuracy: 0.2946 - val_loss: 1.1021 - val_accuracy: 0.2895
# Epoch 55/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0997 - accuracy: 0.3482 - val_loss: 1.1064 - val_accuracy: 0.2895
# Epoch 56/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1090 - accuracy: 0.3125 - val_loss: 1.1037 - val_accuracy: 0.3158
# Epoch 57/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0994 - accuracy: 0.3304 - val_loss: 1.1081 - val_accuracy: 0.2895
# Epoch 58/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1068 - accuracy: 0.3482 - val_loss: 1.1123 - val_accuracy: 0.2895
# Epoch 59/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1027 - accuracy: 0.3036 - val_loss: 1.1034 - val_accuracy: 0.3158
# Epoch 60/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1010 - accuracy: 0.3393 - val_loss: 1.1058 - val_accuracy: 0.3158
# Epoch 61/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1025 - accuracy: 0.2946 - val_loss: 1.1049 - val_accuracy: 0.2895
# Epoch 62/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1014 - accuracy: 0.3482 - val_loss: 1.1149 - val_accuracy: 0.2895
# Epoch 63/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1027 - accuracy: 0.3482 - val_loss: 1.1071 - val_accuracy: 0.2895
# Epoch 64/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1158 - accuracy: 0.2411 - val_loss: 1.0949 - val_accuracy: 0.3947
# Epoch 65/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1001 - accuracy: 0.3125 - val_loss: 1.1123 - val_accuracy: 0.2895
# Epoch 66/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1102 - accuracy: 0.3482 - val_loss: 1.1277 - val_accuracy: 0.2895
# Epoch 67/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1055 - accuracy: 0.3482 - val_loss: 1.1009 - val_accuracy: 0.2895
# Epoch 68/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1059 - accuracy: 0.2321 - val_loss: 1.1000 - val_accuracy: 0.3158
# Epoch 69/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1036 - accuracy: 0.3393 - val_loss: 1.1030 - val_accuracy: 0.3158
# Epoch 70/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1061 - accuracy: 0.3214 - val_loss: 1.1141 - val_accuracy: 0.2895
# Epoch 71/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1125 - accuracy: 0.3482 - val_loss: 1.1267 - val_accuracy: 0.2895
# Epoch 72/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1106 - accuracy: 0.2768 - val_loss: 1.0980 - val_accuracy: 0.3158
# Epoch 73/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1009 - accuracy: 0.3036 - val_loss: 1.1012 - val_accuracy: 0.2895
# Epoch 74/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1057 - accuracy: 0.3482 - val_loss: 1.1096 - val_accuracy: 0.2895
# Epoch 75/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0975 - accuracy: 0.3482 - val_loss: 1.1034 - val_accuracy: 0.2895
# Epoch 76/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1008 - accuracy: 0.3304 - val_loss: 1.1033 - val_accuracy: 0.3158
# Epoch 77/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0999 - accuracy: 0.3393 - val_loss: 1.1058 - val_accuracy: 0.3158
# Epoch 78/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1020 - accuracy: 0.3393 - val_loss: 1.1120 - val_accuracy: 0.2895
# Epoch 79/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1010 - accuracy: 0.3482 - val_loss: 1.1087 - val_accuracy: 0.2895
# Epoch 80/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1012 - accuracy: 0.3304 - val_loss: 1.1038 - val_accuracy: 0.3158
# Epoch 81/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1004 - accuracy: 0.3393 - val_loss: 1.1038 - val_accuracy: 0.3158
# Epoch 82/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1033 - accuracy: 0.3482 - val_loss: 1.1109 - val_accuracy: 0.2895
# Epoch 83/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0997 - accuracy: 0.3482 - val_loss: 1.1047 - val_accuracy: 0.2895
# Epoch 84/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0991 - accuracy: 0.3482 - val_loss: 1.1050 - val_accuracy: 0.2895
# Epoch 85/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1048 - accuracy: 0.2411 - val_loss: 1.0971 - val_accuracy: 0.3158
# Epoch 86/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1066 - accuracy: 0.2857 - val_loss: 1.1133 - val_accuracy: 0.2895
# Epoch 87/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1011 - accuracy: 0.2946 - val_loss: 1.1092 - val_accuracy: 0.3158
# Epoch 88/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0986 - accuracy: 0.3571 - val_loss: 1.1054 - val_accuracy: 0.2895
# Epoch 89/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1004 - accuracy: 0.3482 - val_loss: 1.1008 - val_accuracy: 0.2895
# Epoch 90/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1090 - accuracy: 0.2232 - val_loss: 1.1015 - val_accuracy: 0.3158
# Epoch 91/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1034 - accuracy: 0.2946 - val_loss: 1.1125 - val_accuracy: 0.2895
# Epoch 92/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1005 - accuracy: 0.3482 - val_loss: 1.1099 - val_accuracy: 0.2895
# Epoch 93/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1037 - accuracy: 0.3482 - val_loss: 1.1153 - val_accuracy: 0.2895
# Epoch 94/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1016 - accuracy: 0.3304 - val_loss: 1.1014 - val_accuracy: 0.3158
# Epoch 95/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1076 - accuracy: 0.2411 - val_loss: 1.1037 - val_accuracy: 0.2895
# Epoch 96/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1046 - accuracy: 0.3482 - val_loss: 1.1142 - val_accuracy: 0.2895
# Epoch 97/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0996 - accuracy: 0.3482 - val_loss: 1.1027 - val_accuracy: 0.3158
# Epoch 98/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0997 - accuracy: 0.3393 - val_loss: 1.1038 - val_accuracy: 0.3158
# Epoch 99/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1029 - accuracy: 0.3393 - val_loss: 1.1094 - val_accuracy: 0.3158
# Epoch 100/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0995 - accuracy: 0.3482 - val_loss: 1.1094 - val_accuracy: 0.2895
# Epoch 101/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1005 - accuracy: 0.2946 - val_loss: 1.1039 - val_accuracy: 0.3158
# Epoch 102/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1065 - accuracy: 0.2857 - val_loss: 1.0997 - val_accuracy: 0.2895
# Epoch 103/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1017 - accuracy: 0.3482 - val_loss: 1.1109 - val_accuracy: 0.2895
# Epoch 104/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0999 - accuracy: 0.3482 - val_loss: 1.1159 - val_accuracy: 0.3158
# Epoch 105/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1069 - accuracy: 0.3393 - val_loss: 1.1064 - val_accuracy: 0.3158
# Epoch 106/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0997 - accuracy: 0.3304 - val_loss: 1.1038 - val_accuracy: 0.2895
# Epoch 107/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1030 - accuracy: 0.3482 - val_loss: 1.1067 - val_accuracy: 0.2895
# Epoch 108/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1114 - accuracy: 0.3482 - val_loss: 1.1180 - val_accuracy: 0.2895
# Epoch 109/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0998 - accuracy: 0.3482 - val_loss: 1.1042 - val_accuracy: 0.2895
# Epoch 110/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1012 - accuracy: 0.2679 - val_loss: 1.1005 - val_accuracy: 0.2895
# Epoch 111/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1024 - accuracy: 0.3036 - val_loss: 1.1046 - val_accuracy: 0.3158
# Epoch 112/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1057 - accuracy: 0.2857 - val_loss: 1.1071 - val_accuracy: 0.2895
# Epoch 113/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1006 - accuracy: 0.3482 - val_loss: 1.1114 - val_accuracy: 0.2895
# Epoch 114/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0979 - accuracy: 0.3125 - val_loss: 1.1054 - val_accuracy: 0.3158
# Epoch 115/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1003 - accuracy: 0.3393 - val_loss: 1.0990 - val_accuracy: 0.3158
# Epoch 116/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1091 - accuracy: 0.3393 - val_loss: 1.1067 - val_accuracy: 0.3158
# Epoch 117/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1086 - accuracy: 0.2857 - val_loss: 1.1065 - val_accuracy: 0.2895
# Epoch 118/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1067 - accuracy: 0.3482 - val_loss: 1.1110 - val_accuracy: 0.2895
# Epoch 119/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1003 - accuracy: 0.3482 - val_loss: 1.1051 - val_accuracy: 0.3158
# Epoch 120/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1014 - accuracy: 0.3393 - val_loss: 1.1153 - val_accuracy: 0.3158
# Epoch 121/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1033 - accuracy: 0.3393 - val_loss: 1.1067 - val_accuracy: 0.3158
# Epoch 122/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0989 - accuracy: 0.3571 - val_loss: 1.1042 - val_accuracy: 0.2895
# Epoch 123/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1038 - accuracy: 0.3482 - val_loss: 1.1098 - val_accuracy: 0.2895
# Epoch 124/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0988 - accuracy: 0.3482 - val_loss: 1.1041 - val_accuracy: 0.0526
# Epoch 125/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1017 - accuracy: 0.2857 - val_loss: 1.1012 - val_accuracy: 0.3158
# Epoch 126/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1017 - accuracy: 0.3393 - val_loss: 1.1005 - val_accuracy: 0.3158
# Epoch 127/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1140 - accuracy: 0.3304 - val_loss: 1.1299 - val_accuracy: 0.2895
# Epoch 128/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1027 - accuracy: 0.3482 - val_loss: 1.1098 - val_accuracy: 0.2895
# Epoch 129/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0988 - accuracy: 0.3482 - val_loss: 1.1030 - val_accuracy: 0.2895
# Epoch 130/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1026 - accuracy: 0.2679 - val_loss: 1.0966 - val_accuracy: 0.3158
# Epoch 131/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1056 - accuracy: 0.3393 - val_loss: 1.1041 - val_accuracy: 0.3158
# Epoch 132/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0995 - accuracy: 0.3482 - val_loss: 1.1062 - val_accuracy: 0.2895
# Epoch 133/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1042 - accuracy: 0.3482 - val_loss: 1.1135 - val_accuracy: 0.2895
# Epoch 134/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1001 - accuracy: 0.3482 - val_loss: 1.1128 - val_accuracy: 0.2895
# Epoch 135/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0994 - accuracy: 0.3393 - val_loss: 1.1091 - val_accuracy: 0.3158
# Epoch 136/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1008 - accuracy: 0.3393 - val_loss: 1.1044 - val_accuracy: 0.3158
# Epoch 137/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1009 - accuracy: 0.3393 - val_loss: 1.0986 - val_accuracy: 0.3158
# Epoch 138/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1008 - accuracy: 0.3482 - val_loss: 1.1078 - val_accuracy: 0.2895
# Epoch 139/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1016 - accuracy: 0.2679 - val_loss: 1.1129 - val_accuracy: 0.2895
# Epoch 140/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1001 - accuracy: 0.3482 - val_loss: 1.1131 - val_accuracy: 0.2895
# Epoch 141/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0991 - accuracy: 0.3482 - val_loss: 1.1034 - val_accuracy: 0.2895
# Epoch 142/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0996 - accuracy: 0.3482 - val_loss: 1.1033 - val_accuracy: 0.2895
# Epoch 143/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1023 - accuracy: 0.3482 - val_loss: 1.1024 - val_accuracy: 0.2895
# Epoch 144/250
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1032 - accuracy: 0.2946 - val_loss: 1.1013 - val_accuracy: 0.3158
# Epoch 145/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1021 - accuracy: 0.3036 - val_loss: 1.1068 - val_accuracy: 0.2895
# Epoch 146/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1002 - accuracy: 0.3482 - val_loss: 1.1030 - val_accuracy: 0.2895
# Epoch 147/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1007 - accuracy: 0.3125 - val_loss: 1.1100 - val_accuracy: 0.2895
# Epoch 148/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1003 - accuracy: 0.3482 - val_loss: 1.1087 - val_accuracy: 0.2895
# Epoch 149/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1018 - accuracy: 0.2946 - val_loss: 1.1068 - val_accuracy: 0.3158
# Epoch 150/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1053 - accuracy: 0.3393 - val_loss: 1.0998 - val_accuracy: 0.3158
# Epoch 151/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0990 - accuracy: 0.3393 - val_loss: 1.1073 - val_accuracy: 0.2895
# Epoch 152/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1008 - accuracy: 0.3482 - val_loss: 1.1120 - val_accuracy: 0.2895
# Epoch 153/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1020 - accuracy: 0.3482 - val_loss: 1.1113 - val_accuracy: 0.2895
# Epoch 154/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1013 - accuracy: 0.3482 - val_loss: 1.1041 - val_accuracy: 0.3158
# Epoch 155/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0999 - accuracy: 0.2946 - val_loss: 1.1046 - val_accuracy: 0.2895
# Epoch 156/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1002 - accuracy: 0.3393 - val_loss: 1.1022 - val_accuracy: 0.3158
# Epoch 157/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1003 - accuracy: 0.3393 - val_loss: 1.1094 - val_accuracy: 0.3158
# Epoch 158/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1148 - accuracy: 0.2679 - val_loss: 1.1094 - val_accuracy: 0.2895
# Epoch 159/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1027 - accuracy: 0.3036 - val_loss: 1.1090 - val_accuracy: 0.3158
# Epoch 160/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1002 - accuracy: 0.3393 - val_loss: 1.1026 - val_accuracy: 0.3158
# Epoch 161/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1005 - accuracy: 0.3393 - val_loss: 1.1108 - val_accuracy: 0.3158
# Epoch 162/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1004 - accuracy: 0.2946 - val_loss: 1.1099 - val_accuracy: 0.2895
# Epoch 163/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1011 - accuracy: 0.2679 - val_loss: 1.1043 - val_accuracy: 0.3158
# Epoch 164/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0986 - accuracy: 0.3393 - val_loss: 1.1024 - val_accuracy: 0.2895
# Epoch 165/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1005 - accuracy: 0.3482 - val_loss: 1.1072 - val_accuracy: 0.2895
# Epoch 166/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1009 - accuracy: 0.3482 - val_loss: 1.1063 - val_accuracy: 0.2895
# Epoch 167/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1011 - accuracy: 0.3214 - val_loss: 1.1009 - val_accuracy: 0.3158
# Epoch 168/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1008 - accuracy: 0.3393 - val_loss: 1.1081 - val_accuracy: 0.3158
# Epoch 169/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1016 - accuracy: 0.3393 - val_loss: 1.1100 - val_accuracy: 0.3158
# Epoch 170/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1067 - accuracy: 0.3571 - val_loss: 1.1034 - val_accuracy: 0.2895
# Epoch 171/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1022 - accuracy: 0.3482 - val_loss: 1.1081 - val_accuracy: 0.2895
# Epoch 172/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1037 - accuracy: 0.2768 - val_loss: 1.1107 - val_accuracy: 0.2895
# Epoch 173/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0987 - accuracy: 0.3214 - val_loss: 1.1061 - val_accuracy: 0.2895
# Epoch 174/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1005 - accuracy: 0.3036 - val_loss: 1.1074 - val_accuracy: 0.2895
# Epoch 175/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0985 - accuracy: 0.3482 - val_loss: 1.1024 - val_accuracy: 0.2895
# Epoch 176/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1020 - accuracy: 0.2679 - val_loss: 1.1022 - val_accuracy: 0.3158
# Epoch 177/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0998 - accuracy: 0.3214 - val_loss: 1.1077 - val_accuracy: 0.2895
# Epoch 178/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0997 - accuracy: 0.3482 - val_loss: 1.1043 - val_accuracy: 0.2895
# Epoch 179/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0990 - accuracy: 0.3482 - val_loss: 1.1080 - val_accuracy: 0.2895
# Epoch 180/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1035 - accuracy: 0.3482 - val_loss: 1.1010 - val_accuracy: 0.2895
# Epoch 181/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0999 - accuracy: 0.3482 - val_loss: 1.1131 - val_accuracy: 0.2895
# Epoch 182/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1001 - accuracy: 0.3482 - val_loss: 1.1149 - val_accuracy: 0.2895
# Epoch 183/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0999 - accuracy: 0.2857 - val_loss: 1.1087 - val_accuracy: 0.3158
# Epoch 184/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1052 - accuracy: 0.2679 - val_loss: 1.1036 - val_accuracy: 0.2895
# Epoch 185/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1035 - accuracy: 0.2679 - val_loss: 1.0952 - val_accuracy: 0.3947
# Epoch 186/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1009 - accuracy: 0.2679 - val_loss: 1.1035 - val_accuracy: 0.2895
# Epoch 187/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0982 - accuracy: 0.3482 - val_loss: 1.1090 - val_accuracy: 0.2895
# Epoch 188/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1005 - accuracy: 0.3214 - val_loss: 1.1049 - val_accuracy: 0.3158
# Epoch 189/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1027 - accuracy: 0.2946 - val_loss: 1.1110 - val_accuracy: 0.2895
# Epoch 190/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0997 - accuracy: 0.3482 - val_loss: 1.1075 - val_accuracy: 0.3158
# Epoch 191/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0999 - accuracy: 0.3304 - val_loss: 1.1033 - val_accuracy: 0.2895
# Epoch 192/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1062 - accuracy: 0.3482 - val_loss: 1.1166 - val_accuracy: 0.2895
# Epoch 193/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0987 - accuracy: 0.3482 - val_loss: 1.1061 - val_accuracy: 0.2895
# Epoch 194/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1021 - accuracy: 0.3125 - val_loss: 1.0981 - val_accuracy: 0.3158
# Epoch 195/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1009 - accuracy: 0.2679 - val_loss: 1.0995 - val_accuracy: 0.2895
# Epoch 196/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1012 - accuracy: 0.3482 - val_loss: 1.1072 - val_accuracy: 0.2895
# Epoch 197/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1033 - accuracy: 0.3482 - val_loss: 1.1195 - val_accuracy: 0.2895
# Epoch 198/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0997 - accuracy: 0.3482 - val_loss: 1.1121 - val_accuracy: 0.3158
# Epoch 199/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0990 - accuracy: 0.3393 - val_loss: 1.1036 - val_accuracy: 0.3158
# Epoch 200/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0995 - accuracy: 0.3125 - val_loss: 1.1011 - val_accuracy: 0.2895
# Epoch 201/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0987 - accuracy: 0.3482 - val_loss: 1.1036 - val_accuracy: 0.2895
# Epoch 202/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1041 - accuracy: 0.3482 - val_loss: 1.1127 - val_accuracy: 0.2895
# Epoch 203/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0996 - accuracy: 0.3304 - val_loss: 1.1089 - val_accuracy: 0.3158
# Epoch 204/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1026 - accuracy: 0.2768 - val_loss: 1.0991 - val_accuracy: 0.2895
# Epoch 205/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1000 - accuracy: 0.2946 - val_loss: 1.0991 - val_accuracy: 0.3158
# Epoch 206/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0989 - accuracy: 0.3393 - val_loss: 1.1051 - val_accuracy: 0.3158
# Epoch 207/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1089 - accuracy: 0.2857 - val_loss: 1.1217 - val_accuracy: 0.2895
# Epoch 208/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1039 - accuracy: 0.3482 - val_loss: 1.1028 - val_accuracy: 0.2895
# Epoch 209/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0983 - accuracy: 0.3482 - val_loss: 1.1023 - val_accuracy: 0.2895
# Epoch 210/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1021 - accuracy: 0.2857 - val_loss: 1.1048 - val_accuracy: 0.3158
# Epoch 211/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0994 - accuracy: 0.3125 - val_loss: 1.1091 - val_accuracy: 0.2895
# Epoch 212/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1003 - accuracy: 0.2768 - val_loss: 1.1047 - val_accuracy: 0.3158
# Epoch 213/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0993 - accuracy: 0.3571 - val_loss: 1.1020 - val_accuracy: 0.2895
# Epoch 214/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1018 - accuracy: 0.3482 - val_loss: 1.1098 - val_accuracy: 0.2895
# Epoch 215/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1025 - accuracy: 0.2857 - val_loss: 1.1096 - val_accuracy: 0.3158
# Epoch 216/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0990 - accuracy: 0.3393 - val_loss: 1.1050 - val_accuracy: 0.3158
# Epoch 217/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1011 - accuracy: 0.3304 - val_loss: 1.1090 - val_accuracy: 0.2895
# Epoch 218/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0993 - accuracy: 0.3482 - val_loss: 1.1011 - val_accuracy: 0.2895
# Epoch 219/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1037 - accuracy: 0.3482 - val_loss: 1.1013 - val_accuracy: 0.2895
# Epoch 220/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0999 - accuracy: 0.3482 - val_loss: 1.1065 - val_accuracy: 0.2895
# Epoch 221/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0983 - accuracy: 0.3304 - val_loss: 1.1066 - val_accuracy: 0.3158
# Epoch 222/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1007 - accuracy: 0.2946 - val_loss: 1.1119 - val_accuracy: 0.2895
# Epoch 223/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1018 - accuracy: 0.3482 - val_loss: 1.1125 - val_accuracy: 0.2895
# Epoch 224/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1005 - accuracy: 0.3482 - val_loss: 1.1032 - val_accuracy: 0.2895
# Epoch 225/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1019 - accuracy: 0.2857 - val_loss: 1.0987 - val_accuracy: 0.3158
# Epoch 226/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1006 - accuracy: 0.3304 - val_loss: 1.1042 - val_accuracy: 0.2895
# Epoch 227/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0994 - accuracy: 0.3214 - val_loss: 1.1023 - val_accuracy: 0.3158
# Epoch 228/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1013 - accuracy: 0.3393 - val_loss: 1.1061 - val_accuracy: 0.3158
# Epoch 229/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0998 - accuracy: 0.3393 - val_loss: 1.1088 - val_accuracy: 0.2895
# Epoch 230/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1055 - accuracy: 0.2411 - val_loss: 1.1102 - val_accuracy: 0.2895
# Epoch 231/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1013 - accuracy: 0.3482 - val_loss: 1.1057 - val_accuracy: 0.2895
# Epoch 232/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0993 - accuracy: 0.3482 - val_loss: 1.1070 - val_accuracy: 0.2895
# Epoch 233/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1062 - accuracy: 0.2232 - val_loss: 1.0981 - val_accuracy: 0.3158
# Epoch 234/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1009 - accuracy: 0.2946 - val_loss: 1.1103 - val_accuracy: 0.3158
# Epoch 235/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1011 - accuracy: 0.3304 - val_loss: 1.1114 - val_accuracy: 0.2895
# Epoch 236/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1035 - accuracy: 0.3482 - val_loss: 1.1023 - val_accuracy: 0.2895
# Epoch 237/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0990 - accuracy: 0.3482 - val_loss: 1.1100 - val_accuracy: 0.2895
# Epoch 238/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1020 - accuracy: 0.3036 - val_loss: 1.1076 - val_accuracy: 0.3158
# Epoch 239/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1028 - accuracy: 0.3393 - val_loss: 1.1043 - val_accuracy: 0.2895
# Epoch 240/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1040 - accuracy: 0.3482 - val_loss: 1.1074 - val_accuracy: 0.2895
# Epoch 241/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1003 - accuracy: 0.3482 - val_loss: 1.1068 - val_accuracy: 0.2895
# Epoch 242/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1015 - accuracy: 0.3482 - val_loss: 1.1101 - val_accuracy: 0.2895
# Epoch 243/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1005 - accuracy: 0.3036 - val_loss: 1.1030 - val_accuracy: 0.3158
# Epoch 244/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0999 - accuracy: 0.2500 - val_loss: 1.1034 - val_accuracy: 0.3158
# Epoch 245/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1018 - accuracy: 0.2857 - val_loss: 1.1078 - val_accuracy: 0.2895
# Epoch 246/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0993 - accuracy: 0.3125 - val_loss: 1.1118 - val_accuracy: 0.3158
# Epoch 247/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0984 - accuracy: 0.3125 - val_loss: 1.1092 - val_accuracy: 0.3158
# Epoch 248/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1017 - accuracy: 0.3393 - val_loss: 1.1054 - val_accuracy: 0.2895
# Epoch 249/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0994 - accuracy: 0.3482 - val_loss: 1.1052 - val_accuracy: 0.2895
# Epoch 250/250
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0994 - accuracy: 0.3482 - val_loss: 1.1063 - val_accuracy: 0.2895

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=16)
print(classification_report(testY.argmax(axis=1),
	predictions.argmax(axis=1), target_names=dataset.target_names))
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#       setosa       0.29      1.00      0.45        11
#   versicolor       0.00      0.00      0.00        15
#    virginica       0.00      0.00      0.00        12
#
#     accuracy                           0.29        38
#    macro avg       0.10      0.33      0.15        38
# weighted avg       0.08      0.29      0.13        38
# /Users/sauln/.virtualenvs/ml/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Another example of classification, but for images...

# %%
# import the necessary packages
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from PIL import Image
from imutils import paths
import numpy as np
import argparse
import os

def extract_color_stats(image):
	# split the input image into its respective RGB color channels
	# and then create a feature vector with 6 values: the mean and
	# standard deviation for each of the 3 channels, respectively
	(R, G, B) = image.split()
	features = [np.mean(R), np.mean(G), np.mean(B), np.std(R),
		np.std(G), np.std(B)]

	# return our set of features
	return features

# construct the argument parser and parse the arguments
#ap = argparse.ArgumentParser()
#ap.add_argument("-d", "--dataset", type=str, default="3scenes",
#	help="path to directory containing the '3scenes' dataset")
#ap.add_argument("-m", "--model", type=str, default="knn",
#	help="type of python machine learning model to use")
#args = vars(ap.parse_args())

# define the dictionary of models our script can use, where the key
# to the dictionary is the name of the model (supplied via command
# line argument) and the value is the model itself
models = {
	"knn": KNeighborsClassifier(n_neighbors=1),
	"naive_bayes": GaussianNB(),
	"logit": LogisticRegression(solver="lbfgs", multi_class="auto"),
	"svm": SVC(kernel="linear"),
	"decision_tree": DecisionTreeClassifier(),
	"random_forest": RandomForestClassifier(n_estimators=100),
	"mlp": MLPClassifier()
}

# grab all image paths in the input dataset directory, initialize our
# list of extracted features and corresponding labels
print("[INFO] extracting image features...")
imagePaths = paths.list_images("3scenes/")
data = []
labels = []

# loop over our input images
for imagePath in imagePaths:
	# load the input image from disk, compute color channel
	# statistics, and then update our data list
	image = Image.open(imagePath)
	features = extract_color_stats(image)
	data.append(features)

	# extract the class label from the file path and update the
	# labels list
	label = imagePath.split(os.path.sep)[-2]
	labels.append(label)

# encode the labels, converting them from strings to integers
le = LabelEncoder()
labels = le.fit_transform(labels)

# perform a training and testing split, using 75% of the data for
# training and 25% for evaluation
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=0.25)

# train the model
print("[INFO] using '{}' model".format("knn"))
model = models["knn"]
model.fit(trainX, trainY)

# make predictions on our data and show a classification report
print("[INFO] evaluating...")
predictions = model.predict(testX)
print(classification_report(testY, predictions, target_names=le.classes_))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-f9f8dac65931> in <module>
#      11 from sklearn.metrics import classification_report
#      12 from PIL import Image
# ---> 13 from imutils import paths
#      14 import numpy as np
#      15 import argparse
#
# ~/.virtualenvs/ml/lib/python3.8/site-packages/imutils/__init__.py in <module>
#       6
#       7 # import the necessary packages
# ----> 8 from .convenience import translate
#       9 from .convenience import rotate
#      10 from .convenience import rotate_bound
#
# ~/.virtualenvs/ml/lib/python3.8/site-packages/imutils/convenience.py in <module>
#       4 # import the necessary packages
#       5 import numpy as np
# ----> 6 import cv2
#       7 import sys
#       8
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# # Example of CNN

# %%
# import the necessary packages
from keras.models import Sequential
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.optimizers import Adam
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from PIL import Image
from imutils import paths
import numpy as np
import argparse
import os


# grab all image paths in the input dataset directory, then initialize
# our list of images and corresponding class labels
print("[INFO] loading images...")
imagePaths = paths.list_images("3scenes/")
data = []
labels = []

# loop over our input images
for imagePath in imagePaths:
	# load the input image from disk, resize it to 32x32 pixels, scale
	# the pixel intensities to the range [0, 1], and then update our
	# images list
	image = Image.open(imagePath)
	image = np.array(image.resize((32, 32))) / 255.0
	data.append(image)

	# extract the class label from the file path and update the
	# labels list
	label = imagePath.split(os.path.sep)[-2]
	labels.append(label)

# encode the labels, converting them from strings to integers
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# perform a training and testing split, using 75% of the data for
# training and 25% for evaluation
(trainX, testX, trainY, testY) = train_test_split(np.array(data),
	np.array(labels), test_size=0.25)

# define our Convolutional Neural Network architecture
model = Sequential()
model.add(Conv2D(8, (3, 3), padding="same", input_shape=(32, 32, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Conv2D(16, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Conv2D(32, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Flatten())
model.add(Dense(3))
model.add(Activation("softmax"))

# train the model using the Adam optimizer
print("[INFO] training network...")
opt = Adam(lr=1e-3, decay=1e-3 / 50)
model.compile(loss="categorical_crossentropy", optimizer=opt,
	metrics=["accuracy"])
H = model.fit(trainX, trainY, validation_data=(testX, testY),
	epochs=50, batch_size=32)

# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=32)
print(classification_report(testY.argmax(axis=1),
	predictions.argmax(axis=1), target_names=lb.classes_))
# Out:
# [INFO] loading images...
# [INFO] training network...
# Epoch 1/50
# 23/23 [==============================] - 0s 16ms/step - loss: 1.0182 - accuracy: 0.4965 - val_loss: 0.9694 - val_accuracy: 0.4388
# Epoch 2/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.8895 - accuracy: 0.5823 - val_loss: 0.8588 - val_accuracy: 0.5992
# Epoch 3/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7558 - accuracy: 0.6948 - val_loss: 0.7301 - val_accuracy: 0.7426
# Epoch 4/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6632 - accuracy: 0.7468 - val_loss: 0.6626 - val_accuracy: 0.6962
# Epoch 5/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5880 - accuracy: 0.7722 - val_loss: 0.6015 - val_accuracy: 0.7806
# Epoch 6/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5514 - accuracy: 0.7961 - val_loss: 0.5151 - val_accuracy: 0.8228
# Epoch 7/50
# 23/23 [==============================] - 0s 11ms/step - loss: 0.4795 - accuracy: 0.8284 - val_loss: 0.4565 - val_accuracy: 0.8059
# Epoch 8/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4437 - accuracy: 0.8200 - val_loss: 0.4843 - val_accuracy: 0.7932
# Epoch 9/50
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3972 - accuracy: 0.8551 - val_loss: 0.4314 - val_accuracy: 0.8439
# Epoch 10/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4146 - accuracy: 0.8439 - val_loss: 0.3899 - val_accuracy: 0.8608
# Epoch 11/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3547 - accuracy: 0.8805 - val_loss: 0.3546 - val_accuracy: 0.8861
# Epoch 12/50
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3306 - accuracy: 0.8889 - val_loss: 0.3148 - val_accuracy: 0.8903
# Epoch 13/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3130 - accuracy: 0.8917 - val_loss: 0.3019 - val_accuracy: 0.8945
# Epoch 14/50
# 23/23 [==============================] - 0s 9ms/step - loss: 0.3137 - accuracy: 0.8931 - val_loss: 0.3024 - val_accuracy: 0.8903
# Epoch 15/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2892 - accuracy: 0.8959 - val_loss: 0.2858 - val_accuracy: 0.8945
# Epoch 16/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2776 - accuracy: 0.9030 - val_loss: 0.4258 - val_accuracy: 0.8312
# Epoch 17/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3144 - accuracy: 0.8776 - val_loss: 0.2907 - val_accuracy: 0.8903
# Epoch 18/50
# 23/23 [==============================] - 0s 9ms/step - loss: 0.2596 - accuracy: 0.8973 - val_loss: 0.2645 - val_accuracy: 0.9072
# Epoch 19/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2406 - accuracy: 0.9255 - val_loss: 0.2666 - val_accuracy: 0.9030
# Epoch 20/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2460 - accuracy: 0.9142 - val_loss: 0.2959 - val_accuracy: 0.8819
# Epoch 21/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2485 - accuracy: 0.8987 - val_loss: 0.2587 - val_accuracy: 0.9198
# Epoch 22/50
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2286 - accuracy: 0.9241 - val_loss: 0.2640 - val_accuracy: 0.9030
# Epoch 23/50
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2837 - accuracy: 0.8861 - val_loss: 0.3224 - val_accuracy: 0.8776
# Epoch 24/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2478 - accuracy: 0.9226 - val_loss: 0.2767 - val_accuracy: 0.9030
# Epoch 25/50
# 23/23 [==============================] - 0s 11ms/step - loss: 0.2177 - accuracy: 0.9269 - val_loss: 0.2584 - val_accuracy: 0.9156
# Epoch 26/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1919 - accuracy: 0.9437 - val_loss: 0.2986 - val_accuracy: 0.9030
# Epoch 27/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2215 - accuracy: 0.9226 - val_loss: 0.2494 - val_accuracy: 0.9114
# Epoch 28/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2096 - accuracy: 0.9212 - val_loss: 0.6256 - val_accuracy: 0.8017
# Epoch 29/50
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2137 - accuracy: 0.9226 - val_loss: 0.2580 - val_accuracy: 0.9198
# Epoch 30/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1928 - accuracy: 0.9283 - val_loss: 0.2781 - val_accuracy: 0.8903
# Epoch 31/50
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1921 - accuracy: 0.9367 - val_loss: 0.2533 - val_accuracy: 0.9156
# Epoch 32/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1630 - accuracy: 0.9536 - val_loss: 0.2475 - val_accuracy: 0.9156
# Epoch 33/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1583 - accuracy: 0.9508 - val_loss: 0.2627 - val_accuracy: 0.9114
# Epoch 34/50
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1652 - accuracy: 0.9494 - val_loss: 0.2198 - val_accuracy: 0.9198
# Epoch 35/50
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1775 - accuracy: 0.9522 - val_loss: 0.2518 - val_accuracy: 0.9156
# Epoch 36/50
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1458 - accuracy: 0.9522 - val_loss: 0.2943 - val_accuracy: 0.8776
# Epoch 37/50
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1414 - accuracy: 0.9550 - val_loss: 0.2276 - val_accuracy: 0.9198
# Epoch 38/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1261 - accuracy: 0.9677 - val_loss: 0.2177 - val_accuracy: 0.9367
# Epoch 39/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1280 - accuracy: 0.9648 - val_loss: 0.2275 - val_accuracy: 0.9241
# Epoch 40/50
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1137 - accuracy: 0.9691 - val_loss: 0.2386 - val_accuracy: 0.9156
# Epoch 41/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1329 - accuracy: 0.9578 - val_loss: 0.2445 - val_accuracy: 0.9198
# Epoch 42/50
# 23/23 [==============================] - 0s 11ms/step - loss: 0.1176 - accuracy: 0.9634 - val_loss: 0.2457 - val_accuracy: 0.9283
# Epoch 43/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1065 - accuracy: 0.9677 - val_loss: 0.2307 - val_accuracy: 0.9283
# Epoch 44/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1146 - accuracy: 0.9634 - val_loss: 0.2759 - val_accuracy: 0.9114
# Epoch 45/50
# 23/23 [==============================] - 0s 10ms/step - loss: 0.1336 - accuracy: 0.9451 - val_loss: 0.2418 - val_accuracy: 0.9241
# Epoch 46/50
# 23/23 [==============================] - 0s 12ms/step - loss: 0.1093 - accuracy: 0.9634 - val_loss: 0.2357 - val_accuracy: 0.9198
# Epoch 47/50
# 23/23 [==============================] - 0s 11ms/step - loss: 0.0983 - accuracy: 0.9719 - val_loss: 0.2298 - val_accuracy: 0.9325
# Epoch 48/50
# 23/23 [==============================] - 0s 11ms/step - loss: 0.0912 - accuracy: 0.9761 - val_loss: 0.2248 - val_accuracy: 0.9325
# Epoch 49/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0893 - accuracy: 0.9705 - val_loss: 0.2209 - val_accuracy: 0.9241
# Epoch 50/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0875 - accuracy: 0.9761 - val_loss: 0.2409 - val_accuracy: 0.9241
# [INFO] evaluating network...
#                  precision    recall  f1-score   support
#
#   3scenes/coast       0.94      0.94      0.94        96
#  3scenes/forest       0.92      0.97      0.94        78
# 3scenes/highway       0.91      0.84      0.88        63
#
#        accuracy                           0.92       237
#       macro avg       0.92      0.92      0.92       237
#    weighted avg       0.92      0.92      0.92       237
